# %% [markdown]
# # importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
filename = "dog classification.jpg"

# %% [markdown]
# # first method

# %%
from IPython.display import Image
Image(filename  = '/content/dog classification.jpg' , width = 224, height = 224)

# %% [markdown]
# # second method

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename , target_size = (224,224))

plt.imshow(img)

# %% [markdown]
# # third method

# %%
import cv2
imgg = cv2.imread(filename)
plt.imshow(cv2.cvtColor(imgg,cv2.COLOR_BGR2RGBA))

# %% [markdown]
# # Fourth method

# %%
from PIL import Image
im = Image.open(filename)
im = im.resize((500,500))
plt.imshow(im);

# %% [markdown]
# # Loading deep learing model

# %%
mobile  = tf.keras.applications.mobilenet.MobileNet() ##deep learning pretrained model

# %% [markdown]
# ## pre- processing

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(fileimg , target_size=(224,224)) ##using second method i.e tensorflow
fileimg = "dog classification.jpg"

# %%
## converting image to array
resized_image = image.img_to_array(img)
final_image = np.expand_dims(resized_image,axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)
final_image.shape ##4Dimensions image
# Out:
# (1, 224, 224, 3)

# %% [markdown]
# ## making predictions

# %%
from tensorflow.keras.applications import imagenet_utils
predictions = mobile.predict(final_image)
results = imagenet_utils.decode_predictions(predictions)
display(results)
# Out:
# [[('n02099601', 'golden_retriever', 0.74279475),
#   ('n02113799', 'standard_poodle', 0.11734464),
#   ('n02093647', 'Bedlington_terrier', 0.06696025),
#   ('n02099712', 'Labrador_retriever', 0.04468762),
#   ('n11879895', 'rapeseed', 0.008639452)]]

# %% [markdown]
# * model predictions **74% golden_retriever**
